# %%
import numpy as np
varr1=np.array([1,2,3,4])
varr2=np.array([1,2,3,4])
varrnew =varr1+varr2
print(varrnew)

# %%
import numpy as np
varr1=np.array([1,2,3,4])
varr2=np.array([1,2,3,4])
varrnew =varr1 - varr2
print(varrnew)

# %%
import numpy as np
varr1=np.array([1,2,3,4])
varrnew =varr1/3
print(varrnew)

# %%
import numpy as np
varr1=np.array([1,2,3,4])
varrnew =varr1*3
print(varrnew)

# %%
import numpy as np
varr1=np.array([1,2,3,4])
varr2=np.array([1,2,3,4])
varrnew =varr1/3+varr2*3
print(varrnew)
