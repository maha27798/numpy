# %%
import numpy as np
varr3 = np.random.rand(5)
print(varr3)

# %%
import numpy as np
varr4 = np.random.randn(3)
print(varr4)

# %%
import numpy as np
varr5 = np.random.randn(8)
print(varr5)

# %%
import numpy as np
varr6= np.random.randint(2,9,4)        #min,max,total
print(varr6)
